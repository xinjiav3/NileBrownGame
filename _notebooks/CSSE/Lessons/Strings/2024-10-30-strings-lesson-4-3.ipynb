# %% [markdown]
# # Understanding Strings in JavaScript
#
# Strings are considered primitive data types in JavaScript. They are immutable, meaning once created, their value cannot change.
#
# ## Formatting
# You can define strings using single (`'`) or double (`"`) quotes, and the indexing starts at 0.
#
# ### Examples:
#
# 1. **Creating Strings**
#    ```javascript
#    console.log('simple way to display strings');
#    ```
# 2. **Using Variables**
#    ```javascript
#    const stringExample = 'another example of printing a string';
#    console.log(stringExample);
#    ```
# 3. **Handling Apostrophes**
#    ```javascript
#    console.log('the dog said \"where is my food\" as the owner left');
#    ```
# 4. **Concatenating Strings**
#    ```javascript
#    const mascot = 'night' + 'hawk';
#    console.log(mascot);
#    ```
# 5. **Concatenating multiple variables**
#    ```javascript
#    const fish1 = 'pufferfish';
#    const fish2 = 'marlin';
#    const fish3 = 'salmon';
#    const favFish = 'My favorite fish species are ' + fish1 + ', ' + fish2 + ', and ' + fish3 + '.';
#    console.log(favFish);
#    ```
# 6. **Template Literals**
#    ```javascript
#    const favFishMethodTwo = `My favorite fish species are ${fish1}, ${fish2}, and ${fish3}.`;
#    console.log(favFishMethodTwo);
#    ```
# 7. **Line Breaks in Template Literals**
#    ```javascript
#    const riddle = `my favorite animal\nhibernates during the winter\nin a cave.`;
#    console.log(riddle);
#    ```
