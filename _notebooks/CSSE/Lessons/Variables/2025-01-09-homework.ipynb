# %% [markdown]
# ## Lesson one homework

# %% [markdown]
# You are in charge of maintaining an illegal arcade. You bought shoddy crappy arcade machines off of Temu and they sadly came with missing information. You need to help put back the missing information to allow your shady customers to lose all their money at your store.

# %% [markdown]
# Create a float variable to make the base score 0.00

# %%
# %%js
# // Would you use Let or Const

# %% [markdown]
# Define a variable playerLimit that cannot be re-assigned and give it a value of 4.

# %%
# %%js

# %% [markdown]
# Create a string variable to store the players name.

# %%
# %%js

# %% [markdown]
# Make a boolean to set gameFunction to false

# %%
# %%js
