# %% [markdown]
# ---
# layout: post
# title: Blackjack
# type: issues
# courses: { csse: {week: 4} }
# ---

# %% [markdown]
# <div class="container my-5">
#     <div class="row text-center">
#         <div class="col-12">
#             <h1>Blackjack</h1>
#         </div>
# </div>
#         <div class="row my-4">
#             <div class="col-12 text-center">
#                 <div id="credits" class="mb-3">
#                     <h3>Credits: <span id="creditAmount">1000</span></h3>
#                 </div>
#                 <div id="bet-controls" class="mb-3">
#                     <input type="number" id="betAmount" value="100" min="1" class="form-control d-inline-block" style="width: 100px;">
#                     <button id="startGame" class="btn btn-primary">Start Game</button>
#                 </div>
#                 <div id="game-controls" style="display: none;">
#                     <button id="hit" class="btn btn-success">Hit</button>
#                     <button id="stand" class="btn btn-danger">Stand</button>
#                 </div>
#                 <div id="message" class="alert mt-3" style="display: none;"></div>
#             </div>
#         </div>
#         <!-- Game Table -->
#         <div class="row">
#             <!-- Dealer's Hand -->
#             <div class="col-12 mb-4">
#                 <div class="card">
#                     <div class="card-header">
#                         <h4>Dealer's Hand <span id="dealerScore"></span></h4>
#                     </div>
#                     <div class="card-body">
#                         <div id="dealerHand" class="d-flex justify-content-center flex-wrap"></div>
#                     </div>
#                 </div>
#             </div>
#             <!-- Player's Hand -->
#             <div class="col-12">
#                 <div class="card">
#                     <div class="card-header">
#                         <h4>Your Hand <span id="playerScore"></span></h4>
#                     </div>
#                     <div class="card-body">
#                         <div id="playerHand" class="d-flex justify-content-center flex-wrap"></div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <!-- CSS -->
#     <style>
#         .playing-card {
#             width: 100px;
#             height: 140px;
#             background-color: white;
#             border: 1px solid #ddd;
#             border-radius: 8px;
#             margin: 5px;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             font-size: 24px;
#             box-shadow: 2px 2px 5px rgba(0,0,0,0.1);
#         }
#         .hearts, .diamonds {
#             color: red;
#         }
#         .spades, .clubs {
#             color: black;
#         }
#     </style>
#     <!-- Game Logic -->
#     <script th:inline="javascript">
#         // Game state
#         let currentGame = null;
#         let playerId = /*[[${session.user.id}]]*/ null;
#     </script>
# </body>
# </html>
